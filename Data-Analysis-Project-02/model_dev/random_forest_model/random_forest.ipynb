# %% [markdown]
# ## **Import Required Libraries**

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import OneHotEncoder,OrdinalEncoder,StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report,f1_score,accuracy_score,recall_score,precision_score
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import GridSearchCV
import warnings
warnings.filterwarnings("ignore",category=FutureWarning)

# %% [markdown]
# ## **Load the Datasets**

# %%
train_data=pd.read_csv("C:\\UOC pdf\\4th Year\\Machine Learning-02\\Data-Analysis-Project-2\\data\\train_data.csv")
test_data=pd.read_csv("C:\\UOC pdf\\4th Year\\Machine Learning-02\\Data-Analysis-Project-2\\data\\test_data.csv")

# %%
train_data=train_data.drop(columns=["Unnamed: 0"],axis=1)
test_data=test_data.drop(columns=["Unnamed: 0"],axis=1)

# %% [markdown]
# ## **Split X_train,Y_train,X_test,Y_test**

# %%
X_train=train_data.drop(columns=["diagnosis"],axis=1)
Y_train=train_data["diagnosis"]
X_test=test_data.drop(columns=["diagnosis"],axis=1)
Y_test=test_data["diagnosis"]

# %%
print(f"Shape of the Training set:{X_train.shape,Y_train.shape}")
print(f"Shape of  the Testing set:{X_test.shape,Y_test.shape}")
# Out:
# Shape of the Training set:((700, 15), (700,))
# Shape of  the Testing set:((300, 15), (300,))

# %% [markdown]
# ## **Build the Pipeline**

# %%
num_cols=X_train.select_dtypes(include="number").columns  ##get the all numerical column names
cat_cols=X_train.select_dtypes(include=["object","category"]).columns ##get the all categorical column names

# %%
nominal_cols=["gender","pem_present","meditation_or_mindfulness"] ##nominal columns
ordinal_cols=["work_status","social_activity_level","exercise_frequency"] ##ordinal columns

# %% [markdown]
# #### **Define the Pipeline**

# %%
ordinal_pipeline=Pipeline(steps=[
    ("Ordinal Encoder",OrdinalEncoder())      ##Ordinal variable pipeline
])
nominal_pieline=Pipeline(steps=[
    ("Nominal Encoder",OneHotEncoder(sparse_output=False,handle_unknown="ignore"))  ##Nominal variable pipeline
])

# %% [markdown]
# #### **Combine Pipeline**

# %%
Transfomers=ColumnTransformer(transformers=[
    ("Ordinal Pipeline",ordinal_pipeline,ordinal_cols), ##Combine the Ordinal Pipeline with Ordinal Columns
    ("Nominal Pipeline",nominal_pieline,nominal_cols)   ##Combine the Nominal Pipeline with Nominal Columns
],
   n_jobs=-1,
   verbose=True,
   remainder="drop"
)

# %% [markdown]
# #### **End Pipeline**

# %%
final_pipeline=Pipeline(steps=[
    ("Preprocessing",Transfomers),  ##Preprocessing Step
    ("Resampling SMOTE",SMOTE(random_state=42)),  ##SMOTE Resampling Method
    ("Random Forest Classifier",RandomForestClassifier(max_depth=10,min_samples_split=10,min_samples_leaf=5,random_state=42)) ##Apply random forest classifier
])

# %% [markdown]
# #### **Execute Pipeline**

# %%
final_pipeline.fit(X_train,Y_train)  ## Execute the Final Pipeline
# Out:
# Pipeline(steps=[('Preprocessing',
#                  ColumnTransformer(n_jobs=-1,
#                                    transformers=[('Ordinal Pipeline',
#                                                   Pipeline(steps=[('Ordinal '
#                                                                    'Encoder',
#                                                                    OrdinalEncoder())]),
#                                                   ['work_status',
#                                                    'social_activity_level',
#                                                    'exercise_frequency']),
#                                                  ('Nominal Pipeline',
#                                                   Pipeline(steps=[('Nominal '
#                                                                    'Encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   ['gender', 'pem_present',
#                                                    'meditation_or_mindfulness'])],
#                                    verbose=True)),
#                 ('Resampling SMOTE', SMOTE(random_state=42)),
#                 ('Random Forest Classifier',
#                  RandomForestClassifier(max_depth=10, min_samples_leaf=5,
#                                         min_samples_split=10,
#                                         random_state=42))])

# %% [markdown]
# ## **Model Evaluation**

# %%
Y_pred=final_pipeline.predict(X_test) ##get the prediction values

# %%
report_rf=classification_report(Y_test,Y_pred) ##get the classification report for predictions

# %%
Y_pred_train=final_pipeline.predict(X_train) ##get the preidction value for training set

# %%
report_rf_train=classification_report(Y_train,Y_pred_train) ##get the classification report for training

# %% [markdown]
# #### **Get the Evaluation Metrics for Testing Data**

# %%
f1_test=f1_score(Y_test,Y_pred,average='weighted') ##F1 score for testing data
precision_test=precision_score(Y_test,Y_pred,average="weighted") ##precision for testing data
accuracy_test=accuracy_score(Y_test,Y_pred) ## accuracy score for testing data
recall_test=recall_score(Y_test,Y_pred,average="weighted") ## recall score for testing data

# %%
# Print results
print(f"Accuracy:  {accuracy_test:.4f}")
print(f"Precision: {precision_test:.4f}")
print(f"F1 Score:  {f1_test:.4f}")
print(f"Recall Score: {recall_test:.4f}")
# Out:
# Accuracy:  0.8067
# Precision: 0.7990
# F1 Score:  0.8020
# Recall Score: 0.8067

# %% [markdown]
# #### **Get the Evaluation Metrics for Training Data**

# %%
f1_train=f1_score(Y_train,Y_pred_train,average="weighted") ##F1 score for training data
precision_train=precision_score(Y_train,Y_pred_train,average="weighted") ## precision score for training data
accuracy_train=accuracy_score(Y_train,Y_pred_train) ## accuracy score for training data
recall_train=recall_score(Y_train,Y_pred_train,average="weighted") ##recall score for training data

# %%
# Print results
print(f"Accuracy:  {accuracy_train:.4f}")
print(f"Precision: {precision_train:.4f}")
print(f"F1 Score:  {f1_train:.4f}")
print(f"Recall Score:{recall_train:.4f}")
# Out:
# Accuracy:  0.8414
# Precision: 0.8380
# F1 Score:  0.8390
# Recall Score:0.8414

# %%
### print the classification report for testing data
print(report_rf)
# Out:
#               precision    recall  f1-score   support
#
#         Both       0.46      0.39      0.42        54
#   Depression       1.00      1.00      1.00       125
#       ME/CFS       0.74      0.79      0.77       121
#
#     accuracy                           0.81       300
#    macro avg       0.73      0.73      0.73       300
# weighted avg       0.80      0.81      0.80       300

# %%
## print the classification report for training data
print(report_rf_train)
# Out:
#               precision    recall  f1-score   support
#
#         Both       0.64      0.57      0.60       148
#   Depression       1.00      1.00      1.00       276
#       ME/CFS       0.78      0.83      0.80       276
#
#     accuracy                           0.84       700
#    macro avg       0.81      0.80      0.80       700
# weighted avg       0.84      0.84      0.84       700

# %% [markdown]
# ## **Hyperparameter Tune using Grid  SearchCV**

# %%
param_grid = {
    'Random Forest Classifier__n_estimators': [100, 200, 300],
    'Random Forest Classifier__max_depth': [None,5,10,15],
    'Random Forest Classifier__min_samples_split': [2, 5, 10],
    'Random Forest Classifier__min_samples_leaf': [1, 2, 4,5],
    'Random Forest Classifier__max_features': ['sqrt', 'log2'],
    'Random Forest Classifier__bootstrap': [True, False],
    'Random Forest Classifier__criterion': ['gini', 'entropy']
}

# %%
grid_search=GridSearchCV(final_pipeline,param_grid=param_grid,cv=5,scoring="f1_weighted")

# %% [markdown]
# #### **Execute the Pipeline**

# %%
grid_search.fit(X_train,Y_train) ##execute the whole pipeline
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('Preprocessing',
#                                         ColumnTransformer(n_jobs=-1,
#                                                           transformers=[('Ordinal '
#                                                                          'Pipeline',
#                                                                          Pipeline(steps=[('Ordinal '
#                                                                                           'Encoder',
#                                                                                           OrdinalEncoder())]),
#                                                                          ['work_status',
#                                                                           'social_activity_level',
#                                                                           'exercise_frequency']),
#                                                                         ('Nominal '
#                                                                          'Pipeline',
#                                                                          Pipeline(steps=[('Nominal '
#                                                                                           'Encoder',
#                                                                                           OneHotEncoder(handle_unknown='ignore',
#                                                                                                         sparse_output...
#              param_grid={'Random Forest Classifier__bootstrap': [True, False],
#                          'Random Forest Classifier__criterion': ['gini',
#                                                                  'entropy'],
#                          'Random Forest Classifier__max_depth': [None, 5, 10,
#                                                                  15],
#                          'Random Forest Classifier__max_features': ['sqrt',
#                                                                     'log2'],
#                          'Random Forest Classifier__min_samples_leaf': [1, 2, 4,
#                                                                         5],
#                          'Random Forest Classifier__min_samples_split': [2, 5,
#                                                                          10],
#                          'Random Forest Classifier__n_estimators': [100, 200,
#                                                                     300]},
#              scoring='f1_weighted')

# %% [markdown]
# #### **Best Model**

# %%
best_parameters=grid_search.best_params_
print(best_parameters)
# Out:
# {'Random Forest Classifier__bootstrap': False, 'Random Forest Classifier__criterion': 'gini', 'Random Forest Classifier__max_depth': 15, 'Random Forest Classifier__max_features': 'sqrt', 'Random Forest Classifier__min_samples_leaf': 1, 'Random Forest Classifier__min_samples_split': 2, 'Random Forest Classifier__n_estimators': 200}

# %%
best_model=grid_search.best_estimator_

# %%
best_model
# Out:
# Pipeline(steps=[('Preprocessing',
#                  ColumnTransformer(n_jobs=-1,
#                                    transformers=[('Ordinal Pipeline',
#                                                   Pipeline(steps=[('Ordinal '
#                                                                    'Encoder',
#                                                                    OrdinalEncoder())]),
#                                                   ['work_status',
#                                                    'social_activity_level',
#                                                    'exercise_frequency']),
#                                                  ('Nominal Pipeline',
#                                                   Pipeline(steps=[('Nominal '
#                                                                    'Encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   ['gender', 'pem_present',
#                                                    'meditation_or_mindfulness'])],
#                                    verbose=True)),
#                 ('Resampling SMOTE', SMOTE(random_state=42)),
#                 ('Random Forest Classifier',
#                  RandomForestClassifier(bootstrap=False, max_depth=15,
#                                         n_estimators=200, random_state=42))])

# %% [markdown]
# ## **Model Evaluation**

# %%
Y_pred_cv=best_model.predict(X_test) ##get the prediction values

# %%
report_rf_cv=classification_report(Y_test,Y_pred_cv) ##get the classification report for predictions

# %%
Y_pred_train_cv=best_model.predict(X_train) ##get the preidction value for training set

# %%
report_rf_train_cv=classification_report(Y_train,Y_pred_train_cv) ##get the classification report for training

# %% [markdown]
# #### **Get the Evaluation Metrics for Testing Data**

# %%
f1_test=f1_score(Y_test,Y_pred_cv,average='weighted') ##F1 score for testing data
precision_test=precision_score(Y_test,Y_pred_cv,average="weighted") ##precision for testing data
accuracy_test=accuracy_score(Y_test,Y_pred_cv) ## accuracy score for testing data
recall_test=recall_score(Y_test,Y_pred_cv,average="weighted") ## recall score for testing data

# %%
# Print results
print(f"Accuracy:  {accuracy_test:.4f}")
print(f"Precision: {precision_test:.4f}")
print(f"F1 Score:  {f1_test:.4f}")
print(f"Recall Score: {recall_test:.4f}")
# Out:
# Accuracy:  0.7833
# Precision: 0.7822
# F1 Score:  0.7828
# Recall Score: 0.7833

# %% [markdown]
# #### **Get the Evaluation Metrics for Training Data**

# %%
f1_train=f1_score(Y_train,Y_pred_train_cv,average="weighted") ##F1 score for training data
precision_train=precision_score(Y_train,Y_pred_train_cv,average="weighted") ## precision score for training data
accuracy_train=accuracy_score(Y_train,Y_pred_train_cv) ## accuracy score for training data
recall_train=recall_score(Y_train,Y_pred_train_cv,average="weighted") ##recall score for training data

# %%
# Print results
print(f"Accuracy:  {accuracy_train:.4f}")
print(f"Precision: {precision_train:.4f}")
print(f"F1 Score:  {f1_train:.4f}")
print(f"Recall Score:{recall_train:.4f}")
# Out:
# Accuracy:  0.8971
# Precision: 0.8971
# F1 Score:  0.8971
# Recall Score:0.8971

# %% [markdown]
# ## **Hyperparameter Tune using Optuna**

# %% [markdown]
# #### **Import Required Libraries**

# %%
import optuna
from sklearn.model_selection import cross_val_score

# %% [markdown]
# #### **Define an Objective Function**

# %%
def objective(trials):
    ##define parameters 
    params = {
        'n_estimators': trials.suggest_int('n_estimators', 100, 1000),
        'max_depth': trials.suggest_int('max_depth', 5, 50),
        'min_samples_split': trials.suggest_int('min_samples_split', 2, 20),
        'min_samples_leaf': trials.suggest_int('min_samples_leaf', 1, 10),
        'max_features': trials.suggest_categorical('max_features', ['sqrt', 'log2', None]),
        'bootstrap': trials.suggest_categorical('bootstrap', [True, False]),
        'criterion': trials.suggest_categorical('criterion', ['gini', 'entropy', 'log_loss']),
        'class_weight': trials.suggest_categorical('class_weight', ['balanced', 'balanced_subsample', None]),
        'n_jobs': -1,
        
    }

    ##Build the pipeline
    pipeline_optuna=Pipeline(steps=[
        ("Preprocessing",Transfomers),
        ("Resampling SMOTE",SMOTE(random_state=42)),
        ("Random Forest Classifier",RandomForestClassifier(**params,random_state=42))
    ])

    ##cross validation score
    score=cross_val_score(pipeline_optuna,X_train,Y_train,cv=5,scoring="f1_weighted")
    return score.mean()

# %% [markdown]
# #### **Run the Optimizer**

# %%
study=optuna.create_study(
    study_name="rf_model"
    ,direction="maximize")
study.optimize(objective,n_trials=50)
# Out:
# [I 2025-07-25 22:27:11,117] A new study created in memory with name: rf_model
# [I 2025-07-25 22:27:17,037] Trial 0 finished with value: 0.7001685130287986 and parameters: {'n_estimators': 304, 'max_depth': 16, 'min_samples_split': 4, 'min_samples_leaf': 10, 'max_features': None, 'bootstrap': True, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 0 with value: 0.7001685130287986.
# [I 2025-07-25 22:27:18,790] Trial 1 finished with value: 0.7278693938634355 and parameters: {'n_estimators': 253, 'max_depth': 17, 'min_samples_split': 7, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'bootstrap': False, 'criterion': 'log_loss', 'class_weight': 'balanced'}. Best is trial 1 with value: 0.7278693938634355.
# [I 2025-07-25 22:27:22,892] Trial 2 finished with value: 0.6912911739601035 and parameters: {'n_estimators': 583, 'max_depth': 27, 'min_samples_split': 11, 'min_samples_leaf': 9, 'max_features': None, 'bootstrap': False, 'criterion': 'log_loss', 'class_weight': 'balanced_subsample'}. Best is trial 1 with value: 0.7278693938634355.
# [I 2025-07-25 22:27:27,907] Trial 3 finished with value: 0.7148742967604088 and parameters: {'n_estimators': 793, 'max_depth': 31, 'min_samples_split': 7, 'min_samples_leaf': 6, 'max_features': 'sqrt', 'bootstrap': False, 'criterion': 'gini', 'class_weight': 'balanced'}. Best is trial 1 with value: 0.7278693938634355.
# [I 2025-07-25 22:27:31,415] Trial 4 finished with value: 0.697564465854457 and parameters: {'n_estimators': 471, 'max_depth': 39, 'min_samples_split': 9, 'min_samples_leaf': 10, 'max_features': 'log2', 'bootstrap': True, 'criterion': 'gini', 'class_weight': 'balanced'}. Best is trial 1 with value: 0.7278693938634355.
# [I 2025-07-25 22:27:34,947] Trial 5 finished with value: 0.6980339834109064 and parameters: {'n_estimators': 532, 'max_depth': 26, 'min_samples_split': 18, 'min_samples_leaf': 8, 'max_features': None, 'bootstrap': False, 'criterion': 'entropy', 'class_weight': 'balanced'}. Best is trial 1 with value: 0.7278693938634355.
# [I 2025-07-25 22:27:40,686] Trial 6 finished with value: 0.7340344647142677 and parameters: {'n_estimators': 782, 'max_depth': 45, 'min_samples_split': 8, 'min_samples_leaf': 1, 'max_features': 'log2', 'bootstrap': False, 'criterion': 'gini', 'class_weight': 'balanced_subsample'}. Best is trial 6 with value: 0.7340344647142677.
# [I 2025-07-25 22:27:43,644] Trial 7 finished with value: 0.7199590872055707 and parameters: {'n_estimators': 285, 'max_depth': 42, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': 'log2', 'bootstrap': True, 'criterion': 'log_loss', 'class_weight': 'balanced'}. Best is trial 6 with value: 0.7340344647142677.
# [I 2025-07-25 22:27:48,369] Trial 8 finished with value: 0.7218735425229748 and parameters: {'n_estimators': 686, 'max_depth': 22, 'min_samples_split': 12, 'min_samples_leaf': 3, 'max_features': 'log2', 'bootstrap': False, 'criterion': 'log_loss', 'class_weight': None}. Best is trial 6 with value: 0.7340344647142677.
# [I 2025-07-25 22:27:49,764] Trial 9 finished with value: 0.7148868370969413 and parameters: {'n_estimators': 128, 'max_depth': 26, 'min_samples_split': 7, 'min_samples_leaf': 6, 'max_features': 'sqrt', 'bootstrap': False, 'criterion': 'log_loss', 'class_weight': 'balanced_subsample'}. Best is trial 6 with value: 0.7340344647142677.
# [I 2025-07-25 22:27:59,287] Trial 10 finished with value: 0.730366994052738 and parameters: {'n_estimators': 944, 'max_depth': 50, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'log2', 'bootstrap': True, 'criterion': 'gini', 'class_weight': 'balanced_subsample'}. Best is trial 6 with value: 0.7340344647142677.
# [I 2025-07-25 22:28:09,642] Trial 11 finished with value: 0.7348819355541665 and parameters: {'n_estimators': 1000, 'max_depth': 50, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'log2', 'bootstrap': True, 'criterion': 'gini', 'class_weight': 'balanced_subsample'}. Best is trial 11 with value: 0.7348819355541665.
# [I 2025-07-25 22:28:20,107] Trial 12 finished with value: 0.7107290555179211 and parameters: {'n_estimators': 980, 'max_depth': 47, 'min_samples_split': 15, 'min_samples_leaf': 1, 'max_features': 'log2', 'bootstrap': True, 'criterion': 'gini', 'class_weight': 'balanced_subsample'}. Best is trial 11 with value: 0.7348819355541665.
# [I 2025-07-25 22:28:28,531] Trial 13 finished with value: 0.7191093304287477 and parameters: {'n_estimators': 800, 'max_depth': 36, 'min_samples_split': 2, 'min_samples_leaf': 3, 'max_features': 'log2', 'bootstrap': True, 'criterion': 'gini', 'class_weight': 'balanced_subsample'}. Best is trial 11 with value: 0.7348819355541665.
# [I 2025-07-25 22:28:33,105] Trial 14 finished with value: 0.7022919732429909 and parameters: {'n_estimators': 842, 'max_depth': 6, 'min_samples_split': 4, 'min_samples_leaf': 4, 'max_features': 'log2', 'bootstrap': False, 'criterion': 'gini', 'class_weight': None}. Best is trial 11 with value: 0.7348819355541665.
# [I 2025-07-25 22:28:47,865] Trial 15 finished with value: 0.7068976763202295 and parameters: {'n_estimators': 891, 'max_depth': 45, 'min_samples_split': 20, 'min_samples_leaf': 5, 'max_features': 'log2', 'bootstrap': True, 'criterion': 'gini', 'class_weight': 'balanced_subsample'}. Best is trial 11 with value: 0.7348819355541665.
# [I 2025-07-25 22:29:01,056] Trial 16 finished with value: 0.7242300021632646 and parameters: {'n_estimators': 700, 'max_depth': 50, 'min_samples_split': 13, 'min_samples_leaf': 1, 'max_features': 'log2', 'bootstrap': True, 'criterion': 'entropy', 'class_weight': 'balanced_subsample'}. Best is trial 11 with value: 0.7348819355541665.
# [I 2025-07-25 22:29:12,441] Trial 17 finished with value: 0.7197929019746011 and parameters: {'n_estimators': 997, 'max_depth': 35, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 'log2', 'bootstrap': False, 'criterion': 'gini', 'class_weight': 'balanced_subsample'}. Best is trial 11 with value: 0.7348819355541665.
# [I 2025-07-25 22:29:22,845] Trial 18 finished with value: 0.7003005842357594 and parameters: {'n_estimators': 716, 'max_depth': 42, 'min_samples_split': 15, 'min_samples_leaf': 7, 'max_features': None, 'bootstrap': True, 'criterion': 'gini', 'class_weight': None}. Best is trial 11 with value: 0.7348819355541665.
# [I 2025-07-25 22:29:30,938] Trial 19 finished with value: 0.7176462115590022 and parameters: {'n_estimators': 618, 'max_depth': 45, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'bootstrap': False, 'criterion': 'gini', 'class_weight': 'balanced_subsample'}. Best is trial 11 with value: 0.7348819355541665.
# [I 2025-07-25 22:29:42,174] Trial 20 finished with value: 0.7194554237562427 and parameters: {'n_estimators': 887, 'max_depth': 32, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_features': 'log2', 'bootstrap': False, 'criterion': 'entropy', 'class_weight': 'balanced_subsample'}. Best is trial 11 with value: 0.7348819355541665.
# [I 2025-07-25 22:30:00,509] Trial 21 finished with value: 0.730366994052738 and parameters: {'n_estimators': 961, 'max_depth': 49, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'log2', 'bootstrap': True, 'criterion': 'gini', 'class_weight': 'balanced_subsample'}. Best is trial 11 with value: 0.7348819355541665.
# [I 2025-07-25 22:30:19,388] Trial 22 finished with value: 0.7315312560142686 and parameters: {'n_estimators': 914, 'max_depth': 50, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'log2', 'bootstrap': True, 'criterion': 'gini', 'class_weight': 'balanced_subsample'}. Best is trial 11 with value: 0.7348819355541665.
# [I 2025-07-25 22:30:30,748] Trial 23 finished with value: 0.7206496468751478 and parameters: {'n_estimators': 775, 'max_depth': 41, 'min_samples_split': 4, 'min_samples_leaf': 2, 'max_features': 'log2', 'bootstrap': True, 'criterion': 'gini', 'class_weight': 'balanced_subsample'}. Best is trial 11 with value: 0.7348819355541665.
# [I 2025-07-25 22:30:40,057] Trial 24 finished with value: 0.7120006355268161 and parameters: {'n_estimators': 895, 'max_depth': 46, 'min_samples_split': 6, 'min_samples_leaf': 4, 'max_features': 'log2', 'bootstrap': True, 'criterion': 'gini', 'class_weight': 'balanced_subsample'}. Best is trial 11 with value: 0.7348819355541665.
# [I 2025-07-25 22:30:46,797] Trial 25 finished with value: 0.7308528158785703 and parameters: {'n_estimators': 854, 'max_depth': 39, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_features': 'log2', 'bootstrap': True, 'criterion': 'gini', 'class_weight': None}. Best is trial 11 with value: 0.7348819355541665.
# [I 2025-07-25 22:30:54,635] Trial 26 finished with value: 0.7263924682685242 and parameters: {'n_estimators': 741, 'max_depth': 44, 'min_samples_split': 9, 'min_samples_leaf': 3, 'max_features': 'log2', 'bootstrap': True, 'criterion': 'gini', 'class_weight': 'balanced_subsample'}. Best is trial 11 with value: 0.7348819355541665.
# [I 2025-07-25 22:31:08,084] Trial 27 finished with value: 0.7233162036744523 and parameters: {'n_estimators': 930, 'max_depth': 50, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 'log2', 'bootstrap': True, 'criterion': 'gini', 'class_weight': 'balanced_subsample'}. Best is trial 11 with value: 0.7348819355541665.
# [I 2025-07-25 22:31:12,585] Trial 28 finished with value: 0.7099456696560145 and parameters: {'n_estimators': 637, 'max_depth': 38, 'min_samples_split': 3, 'min_samples_leaf': 5, 'max_features': 'sqrt', 'bootstrap': False, 'criterion': 'entropy', 'class_weight': 'balanced_subsample'}. Best is trial 11 with value: 0.7348819355541665.
# [I 2025-07-25 22:31:16,053] Trial 29 finished with value: 0.7071346160107581 and parameters: {'n_estimators': 441, 'max_depth': 11, 'min_samples_split': 14, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': True, 'criterion': 'gini', 'class_weight': None}. Best is trial 11 with value: 0.7348819355541665.
# [I 2025-07-25 22:31:25,535] Trial 30 finished with value: 0.7199357240966433 and parameters: {'n_estimators': 843, 'max_depth': 47, 'min_samples_split': 3, 'min_samples_leaf': 2, 'max_features': None, 'bootstrap': True, 'criterion': 'entropy', 'class_weight': 'balanced_subsample'}. Best is trial 11 with value: 0.7348819355541665.
# [I 2025-07-25 22:31:32,845] Trial 31 finished with value: 0.7308528158785703 and parameters: {'n_estimators': 831, 'max_depth': 42, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_features': 'log2', 'bootstrap': True, 'criterion': 'gini', 'class_weight': None}. Best is trial 11 with value: 0.7348819355541665.
# [I 2025-07-25 22:31:40,003] Trial 32 finished with value: 0.7305124905533911 and parameters: {'n_estimators': 876, 'max_depth': 39, 'min_samples_split': 6, 'min_samples_leaf': 1, 'max_features': 'log2', 'bootstrap': True, 'criterion': 'gini', 'class_weight': None}. Best is trial 11 with value: 0.7348819355541665.
# [I 2025-07-25 22:31:46,812] Trial 33 finished with value: 0.7219856324918538 and parameters: {'n_estimators': 928, 'max_depth': 47, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 'log2', 'bootstrap': True, 'criterion': 'gini', 'class_weight': None}. Best is trial 11 with value: 0.7348819355541665.
# [I 2025-07-25 22:31:52,414] Trial 34 finished with value: 0.719565966153152 and parameters: {'n_estimators': 786, 'max_depth': 33, 'min_samples_split': 4, 'min_samples_leaf': 3, 'max_features': 'log2', 'bootstrap': True, 'criterion': 'gini', 'class_weight': None}. Best is trial 11 with value: 0.7348819355541665.
# [I 2025-07-25 22:31:54,866] Trial 35 finished with value: 0.7406511918146624 and parameters: {'n_estimators': 366, 'max_depth': 44, 'min_samples_split': 6, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'bootstrap': False, 'criterion': 'log_loss', 'class_weight': 'balanced'}. Best is trial 35 with value: 0.7406511918146624.
# [I 2025-07-25 22:31:57,678] Trial 36 finished with value: 0.7291895612703729 and parameters: {'n_estimators': 354, 'max_depth': 20, 'min_samples_split': 8, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'bootstrap': False, 'criterion': 'log_loss', 'class_weight': 'balanced'}. Best is trial 35 with value: 0.7406511918146624.
# [I 2025-07-25 22:31:59,199] Trial 37 finished with value: 0.6985946342071815 and parameters: {'n_estimators': 192, 'max_depth': 44, 'min_samples_split': 10, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'bootstrap': False, 'criterion': 'log_loss', 'class_weight': 'balanced'}. Best is trial 35 with value: 0.7406511918146624.
# [I 2025-07-25 22:32:02,507] Trial 38 finished with value: 0.6997831428237644 and parameters: {'n_estimators': 525, 'max_depth': 48, 'min_samples_split': 8, 'min_samples_leaf': 9, 'max_features': 'sqrt', 'bootstrap': False, 'criterion': 'log_loss', 'class_weight': 'balanced'}. Best is trial 35 with value: 0.7406511918146624.
# [I 2025-07-25 22:32:04,908] Trial 39 finished with value: 0.7283288747555099 and parameters: {'n_estimators': 378, 'max_depth': 30, 'min_samples_split': 6, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'bootstrap': False, 'criterion': 'log_loss', 'class_weight': 'balanced'}. Best is trial 35 with value: 0.7406511918146624.
# [I 2025-07-25 22:32:06,756] Trial 40 finished with value: 0.7088498117852307 and parameters: {'n_estimators': 236, 'max_depth': 43, 'min_samples_split': 7, 'min_samples_leaf': 7, 'max_features': 'sqrt', 'bootstrap': False, 'criterion': 'log_loss', 'class_weight': 'balanced'}. Best is trial 35 with value: 0.7406511918146624.
# [I 2025-07-25 22:32:14,858] Trial 41 finished with value: 0.7406368465242071 and parameters: {'n_estimators': 999, 'max_depth': 40, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False, 'criterion': 'log_loss', 'class_weight': 'balanced'}. Best is trial 35 with value: 0.7406511918146624.
# [I 2025-07-25 22:32:22,040] Trial 42 finished with value: 0.7480160525748761 and parameters: {'n_estimators': 998, 'max_depth': 48, 'min_samples_split': 4, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False, 'criterion': 'log_loss', 'class_weight': 'balanced'}. Best is trial 42 with value: 0.7480160525748761.
# [I 2025-07-25 22:32:28,737] Trial 43 finished with value: 0.7367952256604862 and parameters: {'n_estimators': 995, 'max_depth': 41, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False, 'criterion': 'log_loss', 'class_weight': 'balanced'}. Best is trial 42 with value: 0.7480160525748761.
# [I 2025-07-25 22:32:35,247] Trial 44 finished with value: 0.7264879501107127 and parameters: {'n_estimators': 996, 'max_depth': 37, 'min_samples_split': 4, 'min_samples_leaf': 2, 'max_features': None, 'bootstrap': False, 'criterion': 'log_loss', 'class_weight': 'balanced'}. Best is trial 42 with value: 0.7480160525748761.
# [I 2025-07-25 22:32:44,210] Trial 45 finished with value: 0.7367952256604862 and parameters: {'n_estimators': 967, 'max_depth': 40, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False, 'criterion': 'log_loss', 'class_weight': 'balanced'}. Best is trial 42 with value: 0.7480160525748761.
# [I 2025-07-25 22:32:52,246] Trial 46 finished with value: 0.7263471026693841 and parameters: {'n_estimators': 951, 'max_depth': 40, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': None, 'bootstrap': False, 'criterion': 'log_loss', 'class_weight': 'balanced'}. Best is trial 42 with value: 0.7480160525748761.
# [I 2025-07-25 22:32:55,420] Trial 47 finished with value: 0.737332016335434 and parameters: {'n_estimators': 430, 'max_depth': 34, 'min_samples_split': 6, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False, 'criterion': 'log_loss', 'class_weight': 'balanced'}. Best is trial 42 with value: 0.7480160525748761.
# [I 2025-07-25 22:32:58,474] Trial 48 finished with value: 0.7306143747747035 and parameters: {'n_estimators': 405, 'max_depth': 35, 'min_samples_split': 7, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False, 'criterion': 'log_loss', 'class_weight': 'balanced'}. Best is trial 42 with value: 0.7480160525748761.
# [I 2025-07-25 22:33:00,844] Trial 49 finished with value: 0.7191095670972404 and parameters: {'n_estimators': 319, 'max_depth': 23, 'min_samples_split': 6, 'min_samples_leaf': 3, 'max_features': None, 'bootstrap': False, 'criterion': 'log_loss', 'class_weight': 'balanced'}. Best is trial 42 with value: 0.7480160525748761.

# %% [markdown]
# #### **Best Model**

# %%
best_model_optuna=study.best_params
print(f"Best Params:{best_model_optuna}")
# Out:
# Best Params:{'n_estimators': 998, 'max_depth': 48, 'min_samples_split': 4, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False, 'criterion': 'log_loss', 'class_weight': 'balanced'}

# %% [markdown]
# #### **Rebuild the Pipeline with Best Parameters**

# %%
best_pipeline=Pipeline(steps=[
        ("Preprocessing",Transfomers),
        ("Resampling SMOTE",SMOTE(random_state=42)),
        ("Random Forest Classifier",RandomForestClassifier(random_state=42,**best_model_optuna))
    ])

# %% [markdown]
# #### **Train the Model with Best Parameters**

# %%
best_pipeline.fit(X_train,Y_train)
# Out:
# Pipeline(steps=[('Preprocessing',
#                  ColumnTransformer(n_jobs=-1,
#                                    transformers=[('Ordinal Pipeline',
#                                                   Pipeline(steps=[('Ordinal '
#                                                                    'Encoder',
#                                                                    OrdinalEncoder())]),
#                                                   ['work_status',
#                                                    'social_activity_level',
#                                                    'exercise_frequency']),
#                                                  ('Nominal Pipeline',
#                                                   Pipeline(steps=[('Nominal '
#                                                                    'Encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   ['gender', 'pem_present',
#                                                    'meditation_or_mindfulness'])],
#                                    verbose=True)),
#                 ('Resampling SMOTE', SMOTE(random_state=42)),
#                 ('Random Forest Classifier',
#                  RandomForestClassifier(bootstrap=False,
#                                         class_weight='balanced',
#                                         criterion='log_loss', max_depth=48,
#                                         max_features=None, min_samples_split=4,
#                                         n_estimators=998, random_state=42))])

# %% [markdown]
# #### **Evaluate the Model**

# %%
Y_pred_optuna=best_pipeline.predict(X_test) ##get the prediction values

# %%
report_rf_optuna=classification_report(Y_test,Y_pred_optuna) ##get the classification report for predictions

# %%
Y_pred_train_optuna=best_pipeline.predict(X_train) ##get the preidction value for training set

# %%
report_rf_train_optuna=classification_report(Y_train,Y_pred_train_optuna) ##get the classification report for training

# %% [markdown]
# #### **Get the Evaluation Metrics for Testing Data**

# %%
f1_test=f1_score(Y_test,Y_pred_optuna,average='weighted') ##F1 score for testing data
precision_test=precision_score(Y_test,Y_pred_optuna,average="weighted") ##precision for testing data
accuracy_test=accuracy_score(Y_test,Y_pred_optuna) ## accuracy score for testing data
recall_test=recall_score(Y_test,Y_pred_optuna,average="weighted") ## recall score for testing data

# %%
# Print results
print(f"Accuracy:  {accuracy_test:.4f}")
print(f"Precision: {precision_test:.4f}")
print(f"F1 Score:  {f1_test:.4f}")
print(f"Recall Score:{recall_test:.4f}")
# Out:
# Accuracy:  0.7667
# Precision: 0.7714
# F1 Score:  0.7689
# Recall Score:0.7667

# %% [markdown]
# #### **Get the Evaluation Metrics for Training Data**

# %%
f1_train=f1_score(Y_train,Y_pred_train_optuna,average="weighted") ##F1 score for training data
precision_train=precision_score(Y_train,Y_pred_train_optuna,average="weighted") ## precision score for training data
accuracy_train=accuracy_score(Y_train,Y_pred_train_optuna) ## accuracy score for training data
recall_train=recall_score(Y_train,Y_pred_train_optuna,average="weighted") ##recall score for training data

# %%
# Print results
print(f"Accuracy:  {accuracy_train:.4f}")
print(f"Precision: {precision_train:.4f}")
print(f"F1 Score:  {f1_train:.4f}")
print(f"Recall Score:{recall_train:.4f}")
# Out:
# Accuracy:  0.8829
# Precision: 0.8856
# F1 Score:  0.8838
# Recall Score:0.8829

# %% [markdown]
# ## **Model Deployement using Mlflow**

# %%
import mlflow

# %%
import mlflow.sklearn
import mlflow.sklearn


mlflow.set_tracking_uri("http://127.0.0.1:5000/")
mlflow.set_experiment("Random--Forest--Classifier")

##Random Forest without Hyperparamter Tune
with mlflow.start_run(run_name="Random Forest Classifier without Hyperparameter Tune"):
    params={
        "n_estimators":100,
        "criterion":"gini", 
        "max_depth":2, 
        "min_samples_leaf":1,
        "min_weight_fraction_leaf":0, 
        "max_features":"sqrt", 
        "max_leaf_nodes":None, 
        "min_impurity_decrease":0, 
        "bootstrap":True
    }
    mlflow.log_params(params)
    metrics_1={
        "accuracy":accuracy_score(Y_test,Y_pred),
        "f1-score":f1_score(Y_test,Y_pred,average='weighted'),
        "precision":precision_score(Y_test,Y_pred,average="weighted"),
        "recall":recall_score(Y_test,Y_pred,average="weighted")
    }
    for key,value in metrics_1.items():
        mlflow.log_metric(key,value)
    mlflow.sklearn.log_model(final_pipeline,"Random Forest Classifier without Hyperparameter Tune")
    ##############################################################################################
#####Random Forest with Grid Search CV

with mlflow.start_run(run_name="Random Forest Classifier with Grid SearchCV"):
    mlflow.log_params(best_parameters)
    metrics_2={
        "accuracy":accuracy_score(Y_test,Y_pred_cv),
        "f1-score":f1_score(Y_test,Y_pred_cv,average='weighted'),
        "precision":precision_score(Y_test,Y_pred_cv,average="weighted"),
        "recall":recall_score(Y_test,Y_pred_cv,average="weighted")
    }

    for key,value in metrics_2.items():
        mlflow.log_metric(key,value)
    mlflow.sklearn.log_model(best_model,"Random Forest Classifier with Grid SearchCV")
##########################################################################################
### Random Forest with Optuna

with mlflow.start_run(run_name="Random Forest Classifier with Optuna"):
    mlflow.log_params(best_parameters)
    metrics_3={
        "accuracy":accuracy_score(Y_test,Y_pred_optuna),
        "f1-score":f1_score(Y_test,Y_pred_optuna,average='weighted'),
        "precision":precision_score(Y_test,Y_pred_optuna,average="weighted"),
        "recall":recall_score(Y_test,Y_pred_optuna,average="weighted")
    }
    for key,value in metrics_3.items():
        mlflow.log_metric(key,value)
    mlflow.sklearn.log_model(best_pipeline,"Random Forest Classifier with Optuna")
######################################################################################
# Out:
# 2025/07/25 22:35:39 INFO mlflow.tracking.fluent: Experiment with name 'Random--Forest--Classifier' does not exist. Creating a new experiment.
# 2025/07/25 22:35:39 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2025/07/25 22:35:51 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 🏃 View run Random Forest Classifier without Hyperparameter Tune at: http://127.0.0.1:5000/#/experiments/913150392896147392/runs/8fec902f0d614120aaa2ac1dfa04fc71
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/913150392896147392
# 2025/07/25 22:35:51 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2025/07/25 22:35:57 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 🏃 View run Random Forest Classifier with Grid SearchCV at: http://127.0.0.1:5000/#/experiments/913150392896147392/runs/361877da2e25442e97fe77aec9819500
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/913150392896147392
# 2025/07/25 22:35:58 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2025/07/25 22:36:03 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 🏃 View run Random Forest Classifier with Optuna at: http://127.0.0.1:5000/#/experiments/913150392896147392/runs/8e96a49e9e0c4c4ca876d7b0ca9b6e58
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/913150392896147392
